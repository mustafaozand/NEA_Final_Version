# %%
dict = {
    "output" : [1,2,234]
}

print(dict["output"])

dict["output"].clear()

print(dict["output"])
# Out:
# [1, 2, 234]
# []

# %%
dict = {
    "output" : [1,2,234],
    "biases" : None
}

print(dict["outputs"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 6
#       1 dict = {
#       2     "output" : [1,2,234],
#       3     "biases" : None
#       4 }
# ----> 6 print(dict["outputs"])
#
# KeyError: 'outputs'
